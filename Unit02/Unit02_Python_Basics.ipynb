# %% [markdown]
# # Unit02_Python_Basics | Python程式語言基礎實作練習
#
# 本 Notebook 提供 Python 程式語言基礎的實作練習，涵蓋基本語法、變數與資料型態、運算子、控制流程、函式、模組與例外處理等核心概念。
#
# ## 目標
# - 熟悉 Python 基本語法、縮排與註解規則
# - 掌握變數命名、資料型態與型態轉換
# - 理解運算子的種類與使用
# - 掌握控制流程、迴圈與串列生成式
# - 學會定義函式（含預設參數、*args/**kwargs）
# - 了解模組導入與常用內建模組
# - 理解例外處理（try-except-raise）的重要性
# - 應用 Python 解決化工領域問題
#
# 配合教學講義：[Unit02_Python_Basics.md](Unit02_Python_Basics.md)

# %% [markdown]
# ---
# ## 1. Python 基本語法

# %% [markdown]
# ### 1.0 print() 函式
#
# `print()` 是 Python 中最常用的輸出函式。本課程範例大量使用 `print()`，理解其語法能有效提升程式碼閱讀能力。
#
# **基本語法：**  `print(value1, value2, ..., sep=' ', end='\n')`
#
# | 參數 | 預設值 | 說明 |
# |------|--------|------|
# | `value` | — | 要輸出的值，可傳入多個 |
# | `sep` | `' '`（空格）| 多個值之間的分隔符號 |
# | `end` | `'\n'`（換行）| 輸出結尾符號 |

# %%
# ─────────────────────────────────────────
# 基本用法：輸出字串、數值、變數
# ─────────────────────────────────────────
print("\n[基本用法]")
print("Hello, World!")        # 輸出字串
# Out:
# [基本用法]
# Hello, World!

# %%
temperature = 350.0
print(temperature)             # 輸出數值：350.0
print(type(temperature))       # 輸出型態：<class 'float'>
# Out:
# 350.0
# <class 'float'>

# %%
# 同時輸出多個值（預設以空格分隔）
print("溫度：", temperature, "°C")
# Out:
# 溫度： 350.0 °C

# %%
# ─────────────────────────────────────────
# sep 與 end 參數
# ─────────────────────────────────────────

# sep 指定多個值之間的分隔符號
print("2026", "03", "04", sep="-")        # 2026-03-04
print("溫度", "壓力", "流量", sep=" | ")   # 溫度 | 壓力 | 流量

# end 指定結尾符號（預設換行）
print("載入中", end="")
print(" ... 完成")    # 兩個 print 輸出在同一行
# Out:
# 2026-03-04
# 溫度 | 壓力 | 流量
# 載入中 ... 完成

# %%
# ─────────────────────────────────────────
# f-string 格式化輸出（本課程最常用）
# ─────────────────────────────────────────
name = "CSTR"
temp = 375.2
conversion = 0.857

# 基本 f-string：在字串前加 f，用 {} 包住變數
print(f"反應器類型：{name}")
print(f"溫度：{temp} °C")

# :.Nf 控制小數位數
print(f"溫度（1位小數）：{temp:.1f} °C")     # 375.2 °C
print(f"溫度（4位小數）：{temp:.4f} °C")     # 375.2000 °C

# :.2% 輸出百分比
print(f"轉化率：{conversion:.2%}")            # 85.70%

# :.2e 科學記號
k = 0.00123456
print(f"反應速率常數：{k:.2e} 1/s")          # 1.23e-03 1/s
# Out:
# 反應器類型：CSTR
# 溫度：375.2 °C
# 溫度（1位小數）：375.2 °C
# 溫度（4位小數）：375.2000 °C
# 轉化率：85.70%
# 反應速率常數：1.23e-03 1/s

# %%
# ─────────────────────────────────────────
# 常見格式規範速查
# ─────────────────────────────────────────
print("\n[格式規範速查]")
val = 3.14159

print(f":.2f  → {val:.2f}")      # 固定 2 位小數
print(f":.4f  → {val:.4f}")      # 固定 4 位小數
print(f":.2e  → {val:.2e}")      # 科學記號
print(f":.2%  → {0.856:.2%}")    # 百分比
print(f":>10.2f → {val:>10.2f}") # 右對齊，欄寬 10
print(f":<10.2f → {val:<10.2f}") # 左對齊，欄寬 10
# Out:
# [格式規範速查]
# :.2f  → 3.14
# :.4f  → 3.1416
# :.2e  → 3.14e+00
# :.2%  → 85.60%
# :>10.2f →       3.14
# :<10.2f → 3.14

# %% [markdown]
# ### 1.1 註解 (Comments)

# %%
# 1.1 註解 (Comments)
print("=== 1.1 註解 ===")

# 這是單行註解
# Python 使用 # 符號來標示單行註解

# 多行註解（慣例使用三引號字串）
"""
這是多行註解
可以跨越多行
通常用於函式或模組的說明文件
"""

# 計算圓的面積
radius = 5
area = 3.14159 * radius ** 2  # 使用半徑計算面積
print(f"圓的面積： {area:.2f}")
# Out:
# === 1.1 註解 ===
# 圓的面積： 78.54

# %% [markdown]
# ### 1.2 縮排 (Indentation)

# %%
# 1.2 縮排 (Indentation)
print("\n=== 1.2 縮排 ===")

temperature = 105.0

# 正確的縮排（4 個空格）
if temperature > 100:
    print("水已沸騰")       # 縮排 4 格
    print("請小心燙傷")     # 同一區塊，縮排相同

# 巢狀縮排
pressure = 11.0
if temperature > 100:
    if pressure > 10:
        print("高溫且高壓")  # 巢狀縮排 8 格
# Out:
# === 1.2 縮排 ===
# 水已沸騰
# 請小心燙傷
# 高溫且高壓

# %% [markdown]
# ### 1.3 程式碼執行順序

# %%
# 1.3 程式碼執行順序
print("\n=== 1.3 執行順序 ===")
print("第一行：初始化")
print("第二行：計算")
print("第三行：輸出結果")
# Out:
# === 1.3 執行順序 ===
# 第一行：初始化
# 第二行：計算
# 第三行：輸出結果

# %% [markdown]
# ---
# ## 2. 變數與基本資料型態

# %%
# 2.1 數值型態
print("=== 數值型態 ===")

# 整數
count = 100
negative_num = -50
print(f"整數： {count}, {negative_num}")
print(f"型態： {type(count)}")
# Out:
# === 數值型態 ===
# 整數： 100, -50
# 型態： <class 'int'>

# %%
# 浮點數
temperature = 25.5
pressure = 1.013e5  # 科學記號
print(f"\n浮點數： {temperature}, {pressure}")
print(f"型態： {type(temperature)}")
# Out:
# 浮點數： 25.5, 101300.0
# 型態： <class 'float'>

# %%
# 複數
impedance = 3 + 4j
print(f"\n複數： {impedance}")
print(f"型態： {type(impedance)}")
# Out:
# 複數： (3+4j)
# 型態： <class 'complex'>

# %%
# 2.2 字串操作
print("\n=== 字串操作 ===")

name = "Chemical Engineering"
university = 'Feng Chia University'
# Out:
# === 字串操作 ===

# %%
# 字串連接
greeting = "Hello, " + name
print(greeting)
# Out:
# Hello, Chemical Engineering

# %%
# 字串重複
repeat = "Python " * 3
print(repeat)
# Out:
# Python Python Python

# %%
# 字串長度
print(f"字串長度： {len(name)}")
# Out:
# 字串長度： 20

# %%
# 字串索引與切片
text = "Python"
print(f"第一個字元： {text[0]}")
print(f"最後一個字元： {text[-1]}")
print(f"前三個字元： {text[0:3]}")
# Out:
# 第一個字元： P
# 最後一個字元： n
# 前三個字元： Pyt

# %%
# 字串方法
print(f"轉大寫： {text.upper()}")
print(f"轉小寫： {text.lower()}")
print(f"取代字元： {text.replace('P', 'J')}")
# Out:
# 轉大寫： PYTHON
# 轉小寫： python
# 取代字元： Jython

# %%
# 2.3 布林值
print("\n=== 布林值 ===")

is_running = True
is_stopped = False

print(f"布林值： {is_running}, {is_stopped}")
print(f"比較運算： 10 > 5 = {10 > 5}")
print(f"邏輯運算： True and False = {True and False}")
print(f"邏輯運算： True or False = {True or False}")
print(f"邏輯運算： not True = {not True}")
# Out:
# === 布林值 ===
# 布林值： True, False
# 比較運算： 10 > 5 = True
# 邏輯運算： True and False = False
# 邏輯運算： True or False = True
# 邏輯運算： not True = False

# %%
# 2.4 變數命名規則
print("=== 變數命名規則 ===")

# 合法的變數名稱
temperature = 25.5        # 使用有意義的名稱
flow_rate = 100           # 使用底線分隔 (snake_case)
GRAVITY = 9.81            # 常數使用全大寫

# 不合法的變數名稱（下方為說明，執行會產生 SyntaxError）
# 1st_variable = 10       # ❌ 不能以數字開頭
# my-variable = 20        # ❌ 不能使用連字號
# class = 30              # ❌ 不能使用 Python 關鍵字（class, for, if...）

# Python 動態型別：無需事先宣告型態
x = 10          # int
x = 10.5        # float（自動更換型態）
x = "hello"     # str

print(f"temperature = {temperature}  (型態: {type(temperature).__name__})")
print(f"flow_rate   = {flow_rate}  (型態: {type(flow_rate).__name__})")
print(f"GRAVITY     = {GRAVITY}  (型態: {type(GRAVITY).__name__})")
print(f"\n同一變數 x 形態變化：")
print(f"  x = 10    → {type(10).__name__}")
print(f"  x = 10.5  → {type(10.5).__name__}")
print(f"  x = 'hi'  → {type('hi').__name__}")
# Out:
# === 變數命名規則 ===
# temperature = 25.5  (型態: float)
# flow_rate   = 100  (型態: int)
# GRAVITY     = 9.81  (型態: float)
#
# 同一變數 x 形態變化：
#   x = 10    → int
#   x = 10.5  → float
#   x = 'hi'  → str

# %% [markdown]
# ---
# ### 2.3 資料結構

# %%
# 2.3.1 串列 (List)
print("=== 串列 (List) ===")

temperatures = [25.5, 26.0, 24.8, 25.2, 26.5]
print(f"溫度記錄： {temperatures}")
# Out:
# === 串列 (List) ===
# 溫度記錄： [25.5, 26.0, 24.8, 25.2, 26.5]

# %%
# 串列操作
temperatures.append(27.0)
print(f"新增元素後： {temperatures}")
# Out:
# 新增元素後： [25.5, 26.0, 24.8, 25.2, 26.5, 27.0]

# %%
temperatures.remove(26.0)
print(f"移除元素後： {temperatures}")
# Out:
# 移除元素後： [25.5, 24.8, 25.2, 26.5, 27.0]

# %%
# 串列索引
print(f"第一個溫度： {temperatures[0]}°C")
print(f"最後一個溫度： {temperatures[-1]}°C")
print(f"前三個溫度： {temperatures[0:3]}")
# Out:
# 第一個溫度： 25.5°C
# 最後一個溫度： 27.0°C
# 前三個溫度： [25.5, 24.8, 25.2]

# %%
# 串列統計
print(f"串列長度： {len(temperatures)}")
print(f"最高溫度： {max(temperatures)}°C")
print(f"最低溫度： {min(temperatures)}°C")
print(f"平均溫度： {sum(temperatures)/len(temperatures):.2f}°C")
# Out:
# 串列長度： 5
# 最高溫度： 27.0°C
# 最低溫度： 24.8°C
# 平均溫度： 25.80°C

# %%
# 2.3.2 元組 (Tuple)
print("\n=== 元組 (Tuple) ===")

coordinates = (25.0, 120.5)
reactor_config = ("CSTR", 100, 350.0)

print(f"座標： {coordinates}")
print(f"反應器配置： {reactor_config}")
# Out:
# === 元組 (Tuple) ===
# 座標： (25.0, 120.5)
# 反應器配置： ('CSTR', 100, 350.0)

# %%
# 元組解包
x, y = coordinates
reactor_type, volume, temp = reactor_config

print(f"座標 X: {x}, Y: {y}")
print(f"反應器類型： {reactor_type}, 體積： {volume} L, 溫度： {temp}°C")

# 2.3.3 字典 (Dictionary)
print("\n=== 字典 (Dictionary) ===")

reactor = {
    "type": "CSTR",
    "volume": 100,
    "temperature": 350.0,
    "pressure": 10.0
}

print(f"反應器資訊： {reactor}")
print(f"反應器類型： {reactor['type']}")
print(f"操作溫度： {reactor.get('temperature')}°C")
# Out:
# 座標 X: 25.0, Y: 120.5
# 反應器類型： CSTR, 體積： 100 L, 溫度： 350.0°C
#
# === 字典 (Dictionary) ===
# 反應器資訊： {'type': 'CSTR', 'volume': 100, 'temperature': 350.0, 'pressure': 10.0}
# 反應器類型： CSTR
# 操作溫度： 350.0°C

# %%
# 修改字典
reactor["temperature"] = 360.0
reactor["catalyst"] = "Platinum"
print(f"更新後的反應器資訊： {reactor}")
# Out:
# 更新後的反應器資訊： {'type': 'CSTR', 'volume': 100, 'temperature': 360.0, 'pressure': 10.0, 'catalyst': 'Platinum'}

# %%
# 字典操作
print(f"\n所有鍵： {list(reactor.keys())}")
print(f"所有值： {list(reactor.values())}")
# Out:
# 所有鍵： ['type', 'volume', 'temperature', 'pressure', 'catalyst']
# 所有值： ['CSTR', 100, 360.0, 10.0, 'Platinum']

# %%
# 遍歷字典
print("\n反應器參數：")
for key, value in reactor.items():
    print(f"  {key}: {value}")
# Out:
# 反應器參數：
#   type: CSTR
#   volume: 100
#   temperature: 360.0
#   pressure: 10.0
#   catalyst: Platinum

# %%
# 2.3.4 集合 (Set)
print("\n=== 集合 (Set) ===")

elements1 = {"H", "O", "N", "C"}
elements2 = {"C", "N", "S", "P"}

print(f"元素集合1： {elements1}")
print(f"元素集合2： {elements2}")
# Out:
# === 集合 (Set) ===
# 元素集合1： {'C', 'O', 'N', 'H'}
# 元素集合2： {'C', 'S', 'N', 'P'}

# %%
# 集合運算
print(f"聯集： {elements1 | elements2}")
print(f"交集： {elements1 & elements2}")
print(f"差集： {elements1 - elements2}")
# Out:
# 聯集： {'S', 'C', 'N', 'H', 'O', 'P'}
# 交集： {'C', 'N'}
# 差集： {'O', 'H'}

# %%
# 2.4 型態轉換 (Type Conversion)
print("=== 型態轉換 ===")

# 數值型態轉換
x_int   = int(3.99)      # 3   (截斷小數，不四捨五入)
y_float = float("2.5")   # 2.5
z_str   = str(100)       # "100"

print(f"int(3.99)    = {x_int}   (型態: {type(x_int).__name__})")
print(f"float('2.5') = {y_float} (型態: {type(y_float).__name__})")
print(f"str(100)     = {z_str!r} (型態: {type(z_str).__name__})")

# 字串轉數值
num_str   = "123"
num_int   = int(num_str)     # 123
num_float = float(num_str)   # 123.0
print(f"\nint('123')   = {num_int}")
print(f"float('123') = {num_float}")

# 串列、元組、集合相互轉換
my_list  = [1, 2, 3, 2, 1]
my_tuple = tuple(my_list)   # (1, 2, 3, 2, 1)
my_set   = set(my_list)     # {1, 2, 3} (去除重複)
back_to_list = list(my_set)

print(f"\nlist  → tuple: {my_tuple}")
print(f"list  → set  : {my_set}  (去除重複)")

# 字串與串列互換
text      = "H2O"
char_list = list(text)          # ['H', '2', 'O']
joined    = "".join(char_list)  # 'H2O'

print(f"\nlist('H2O')        = {char_list}")
print(f"''.join(char_list) = {joined!r}")

# 化工應用：讀入字串數據並轉換
raw_data = ["25.5", "26.0", "24.8"]
float_data = [float(val) for val in raw_data]
print(f"\n字串數據轉浮點數： {float_data}")
# Out:
# === 型態轉換 ===
# int(3.99)    = 3   (型態: int)
# float('2.5') = 2.5 (型態: float)
# str(100)     = '100' (型態: str)
#
# int('123')   = 123
# float('123') = 123.0
#
# list  → tuple: (1, 2, 3, 2, 1)
# list  → set  : {1, 2, 3}  (去除重複)
#
# list('H2O')        = ['H', '2', 'O']
# ''.join(char_list) = 'H2O'
#
# 字串數據轉浮點數： [25.5, 26.0, 24.8]

# %% [markdown]
# ---
# ## 3. 運算子 (Operators)

# %%
# 3.1 算術運算子
print("=== 算術運算子 ===")

a = 10
b = 3

print(f"加法：  {a} + {b} = {a + b}")
print(f"減法：  {a} - {b} = {a - b}")
print(f"乘法：  {a} * {b} = {a * b}")
print(f"除法：  {a} / {b} = {a / b:.4f}")
print(f"整除：  {a} // {b} = {a // b}")
print(f"餘數：  {a} % {b} = {a % b}")
print(f"次方：  {a} ** {b} = {a ** b}")

# 化工應用：理想氣體方程式 PV = nRT
print("\n--- 化工應用：莫耳數計算 ---")
pressure = 1.0        # atm
volume = 22.4         # L
R = 0.0821            # L*atm/(mol*K)
temperature = 273.15  # K

moles = (pressure * volume) / (R * temperature)
print(f"莫耳數： {moles:.2f} mol")
# Out:
# === 算術運算子 ===
# 加法：  10 + 3 = 13
# 減法：  10 - 3 = 7
# 乘法：  10 * 3 = 30
# 除法：  10 / 3 = 3.3333
# 整除：  10 // 3 = 3
# 餘數：  10 % 3 = 1
# 次方：  10 ** 3 = 1000
#
# --- 化工應用：莫耳數計算 ---
# 莫耳數： 1.00 mol

# %%
# 3.2 比較運算子
print("=== 比較運算子 ===")

x = 10
y = 5

print(f"{x} == {y}  : {x == y}")   # False (等於)
print(f"{x} != {y}  : {x != y}")   # True  (不等於)
print(f"{x} >  {y}  : {x > y}")    # True  (大於)
print(f"{x} <  {y}  : {x < y}")    # False (小於)
print(f"{x} >= {y}  : {x >= y}")   # True  (大於等於)
print(f"{x} <= {y}  : {x <= y}")   # False (小於等於)

# 化工應用：安全範圍檢查
print("\n--- 化工應用：安全範圍檢查 ---")
reactor_temp = 360.0
MAX_TEMP = 400.0
MIN_TEMP = 300.0

is_safe = (MIN_TEMP <= reactor_temp <= MAX_TEMP)
print(f"反應器溫度： {reactor_temp}°C")
print(f"安全範圍： [{MIN_TEMP}, {MAX_TEMP}]°C")
print(f"是否在安全範圍： {is_safe}")
# Out:
# === 比較運算子 ===
# 10 == 5  : False
# 10 != 5  : True
# 10 >  5  : True
# 10 <  5  : False
# 10 >= 5  : True
# 10 <= 5  : False
#
# --- 化工應用：安全範圍檢查 ---
# 反應器溫度： 360.0°C
# 安全範圍： [300.0, 400.0]°C
# 是否在安全範圍： True

# %%
# 3.3 邏輯運算子
print("=== 邏輯運算子 ===")

temp_ok = True
pressure_ok = False

# and：所有條件都為 True 時才為 True
all_safe = temp_ok and pressure_ok
print(f"temp_ok={temp_ok}, pressure_ok={pressure_ok}")
print(f"and（全部正常）： {all_safe}")

# or：至少一個條件為 True 時就為 True
any_safe = temp_ok or pressure_ok
print(f"or（任一正常）：  {any_safe}")

# not：反轉布林值
not_safe = not temp_ok
print(f"not temp_ok：    {not_safe}")

# 化工應用：製程安全檢查
print("\n--- 化工應用：製程安全檢查 ---")
temperature = 350.0
pressure = 9.5
flow_rate = 95.0

temp_normal     = 300.0 <= temperature <= 400.0
pressure_normal = 8.0   <= pressure    <= 12.0
flow_normal     = 80.0  <= flow_rate   <= 120.0

all_normal = temp_normal and pressure_normal and flow_normal
print(f"溫度正常： {temp_normal} | 壓力正常： {pressure_normal} | 流量正常： {flow_normal}")
print(f"製程狀態正常： {all_normal}")
# Out:
# === 邏輯運算子 ===
# temp_ok=True, pressure_ok=False
# and（全部正常）： False
# or（任一正常）：  True
# not temp_ok：    False
#
# --- 化工應用：製程安全檢查 ---
# 溫度正常： True | 壓力正常： True | 流量正常： True
# 製程狀態正常： True

# %%
# 3.4 賦值運算子
print("=== 賦值運算子 ===")

x = 10
print(f"初始值： x = {x}")

x += 5;  print(f"x += 5  → x = {x}")   # 15
x -= 3;  print(f"x -= 3  → x = {x}")   # 12
x *= 2;  print(f"x *= 2  → x = {x}")   # 24
x /= 4;  print(f"x /= 4  → x = {x}")   # 6.0
x //= 2; print(f"x //= 2 → x = {x}")   # 3.0
x %= 2;  print(f"x %%= 2 → x = {x}")  # 1.0
x **= 3; print(f"x **= 3 → x = {x}")   # 1.0

# 多重賦值與變數交換
print("\n--- 多重賦值與變數交換 ---")
a, b, c = 1, 2, 3
print(f"多重賦值： a={a}, b={b}, c={c}")

a, b = b, a
print(f"交換後：   a={a}, b={b}")
# Out:
# === 賦值運算子 ===
# 初始值： x = 10
# x += 5  → x = 15
# x -= 3  → x = 12
# x *= 2  → x = 24
# x /= 4  → x = 6.0
# x //= 2 → x = 3.0
# x %%= 2 → x = 1.0
# x **= 3 → x = 1.0
#
# --- 多重賦值與變數交換 ---
# 多重賦值： a=1, b=2, c=3
# 交換後：   a=2, b=1

# %% [markdown]
# ---
# ## 4. 控制流程

# %%
# 4.1 條件語句
print("=== 條件語句 (if-elif-else) ===")

# 化工應用：反應器安全檢查
reactor_temp = 375.0  # °C
reactor_pressure = 11.0  # bar

# 溫度檢查
TEMP_MIN, TEMP_MAX = 300.0, 400.0
if reactor_temp < TEMP_MIN:
    temp_status = "偏低"
elif reactor_temp > TEMP_MAX:
    temp_status = "偏高"
else:
    temp_status = "正常"

# 壓力檢查
PRESSURE_MIN, PRESSURE_MAX = 9.0, 12.0
if reactor_pressure < PRESSURE_MIN:
    pressure_status = "偏低"
elif reactor_pressure > PRESSURE_MAX:
    pressure_status = "偏高"
else:
    pressure_status = "正常"

print(f"反應器溫度： {reactor_temp}°C ({temp_status})")
print(f"反應器壓力： {reactor_pressure} bar ({pressure_status})")

# 綜合判斷
if temp_status == "正常" and pressure_status == "正常":
    print("✓ 反應器運作正常")
else:
    print("⚠ 反應器參數異常，請檢查！")
# Out:
# === 條件語句 (if-elif-else) ===
# 反應器溫度： 375.0°C (正常)
# 反應器壓力： 11.0 bar (正常)
# ✓ 反應器運作正常

# %%
# 4.2 for 迴圈
print("\n=== for 迴圈 ===")

# 遍歷串列
temperatures = [25.5, 26.0, 24.8, 25.2, 26.5]
print("溫度記錄：")
for temp in temperatures:
    print(f"  {temp}°C")
# Out:
# === for 迴圈 ===
# 溫度記錄：
#   25.5°C
#   26.0°C
#   24.8°C
#   25.2°C
#   26.5°C

# %%
# 使用 range()
print("\n前5次測量：")
for i in range(5):
    print(f"  第 {i+1} 次測量")
# Out:
# 前5次測量：
#   第 1 次測量
#   第 2 次測量
#   第 3 次測量
#   第 4 次測量
#   第 5 次測量

# %%
# 使用 enumerate() 取得索引
print("\n溫度數據（含索引）：")
for index, temp in enumerate(temperatures, start=1):
    print(f"  第 {index} 筆： {temp}°C")
# Out:
# 溫度數據（含索引）：
#   第 1 筆： 25.5°C
#   第 2 筆： 26.0°C
#   第 3 筆： 24.8°C
#   第 4 筆： 25.2°C
#   第 5 筆： 26.5°C

# %%
# 4.3 串列生成式 (List Comprehension)
print("=== 串列生成式 ===")

# 基本語法： [expression for item in iterable]
squares = [x**2 for x in range(6)]
print(f"平方數串列： {squares}")

# 加入條件： [expression for item in iterable if condition]
even_squares = [x**2 for x in range(10) if x % 2 == 0]
print(f"偶數的平方： {even_squares}")

# 化工應用 1：溫度單位轉換
temps_celsius = [0.0, 25.0, 50.0, 75.0, 100.0]
temps_fahrenheit = [(temp * 9/5) + 32 for temp in temps_celsius]
print(f"\n攝氏溫度： {temps_celsius}")
print(f"華氏溫度： {temps_fahrenheit}")

# 化工應用 2：過濾異常感測器數據
sensor_readings = [25.2, 25.5, -999.0, 25.8, 26.0, 999.9, 26.2]
valid_readings  = [temp for temp in sensor_readings if 0 < temp < 100]
print(f"\n原始讀數：  {sensor_readings}")
print(f"有效讀數：  {valid_readings}")

# 化工應用 3：提取字典欄位
reactor_log = [
    {"time": 0, "temp": 300.0},
    {"time": 1, "temp": 325.5},
    {"time": 2, "temp": 349.8},
]
temps_only = [entry["temp"] for entry in reactor_log]
print(f"\n反應器溫度記錄： {temps_only}")
# Out:
# === 串列生成式 ===
# 平方數串列： [0, 1, 4, 9, 16, 25]
# 偶數的平方： [0, 4, 16, 36, 64]
#
# 攝氏溫度： [0.0, 25.0, 50.0, 75.0, 100.0]
# 華氏溫度： [32.0, 77.0, 122.0, 167.0, 212.0]
#
# 原始讀數：  [25.2, 25.5, -999.0, 25.8, 26.0, 999.9, 26.2]
# 有效讀數：  [25.2, 25.5, 25.8, 26.0, 26.2]
#
# 反應器溫度記錄： [300.0, 325.5, 349.8]

# %%
# 4.4 while 迴圈
print("\n=== while 迴圈 ===")

# 化工應用：批次反應器模擬
import math

print("批次反應器濃度變化模擬")
print("時間(hr)  濃度(mol/L)")
print("-" * 25)

time = 0.0
concentration = 1.0
k = 0.1  # 反應速率常數 (1/hr)

while concentration > 0.1:
    print(f"{time:6.1f}    {concentration:8.4f}")
    time += 0.5
    concentration = 1.0 * math.exp(-k * time)

print(f"\n反應達到目標濃度所需時間： {time:.1f} 小時")
# Out:
# === while 迴圈 ===
# 批次反應器濃度變化模擬
# 時間(hr)  濃度(mol/L)
# -------------------------
#    0.0      1.0000
#    0.5      0.9512
#    1.0      0.9048
#    1.5      0.8607
#    2.0      0.8187
#    2.5      0.7788
#    3.0      0.7408
#    3.5      0.7047
#    4.0      0.6703
#    4.5      0.6376
#    5.0      0.6065
#    5.5      0.5769
#    6.0      0.5488
#    6.5      0.5220
#    7.0      0.4966
#    7.5      0.4724
#    8.0      0.4493
#    8.5      0.4274
#    9.0      0.4066
#    9.5      0.3867
#   10.0      0.3679
#   10.5      0.3499
#   11.0      0.3329
#   11.5      0.3166
#   12.0      0.3012
#   12.5      0.2865
#   13.0      0.2725
#   13.5      0.2592
#   14.0      0.2466
#   14.5      0.2346
#   15.0      0.2231
#   15.5      0.2122
#   16.0      0.2019
#   16.5      0.1920
#   17.0      0.1827
#   17.5      0.1738
#   18.0      0.1653
#   18.5      0.1572
#   19.0      0.1496
#   19.5      0.1423
#   20.0      0.1353
#   20.5      0.1287
#   21.0      0.1225
# ...

# %%
# 4.5 迴圈控制語句
print("=== break、continue、else ===")

# break：立即跳出迴圈
print("--- break 示範 ---")
for i in range(10):
    if i == 5:
        print(f"  找到目標 i={i}，跳出迴圈")
        break
    print(f"  i = {i}")

# continue：跳過當前迭代，繼續下一次
print("\n--- continue 示範（跳過偶數）---")
for i in range(6):
    if i % 2 == 0:
        continue   # 跳過偶數
    print(f"  奇數： {i}")

# else：迴圈正常（未被 break）結束時執行
print("\n--- for-else 示範 ---")
sensor_data = [25.2, 25.5, 25.8, 26.0]
threshold   = 30.0

for temp in sensor_data:
    if temp > threshold:
        print(f"  ⚠ 偵測到異常值： {temp}°C")
        break
else:
    print("  ✓ 所有感測器數值正常")

# 化工應用：感測器資料品質篩選（break + continue）
print("\n--- 化工應用：異常值篩選 ---")
raw_readings  = [25.2, 25.5, 999.9, 25.8, 26.0, -999.0, 26.2]
MAX_VALID_TEMP = 100.0
MIN_VALID_TEMP = 0.0

valid_data = []
for temp in raw_readings:
    if temp > MAX_VALID_TEMP or temp < MIN_VALID_TEMP:
        print(f"  ⚠ 跳過異常值： {temp}°C")
        continue
    valid_data.append(temp)

print(f"  有效資料： {valid_data}")
# Out:
# === break、continue、else ===
# --- break 示範 ---
#   i = 0
#   i = 1
#   i = 2
#   i = 3
#   i = 4
#   找到目標 i=5，跳出迴圈
#
# --- continue 示範（跳過偶數）---
#   奇數： 1
#   奇數： 3
#   奇數： 5
#
# --- for-else 示範 ---
#   ✓ 所有感測器數值正常
#
# --- 化工應用：異常值篩選 ---
#   ⚠ 跳過異常值： 999.9°C
#   ⚠ 跳過異常值： -999.0°C
#   有效資料： [25.2, 25.5, 25.8, 26.0, 26.2]

# %% [markdown]
# ---
# ## 5. 函式

# %%
# 5.1 基本函式
print("=== 基本函式 ===")

def celsius_to_fahrenheit(celsius):
    """將攝氏溫度轉換為華氏溫度"""
    fahrenheit = (celsius * 9/5) + 32
    return fahrenheit

# 使用函式
temp_c = 25.0
temp_f = celsius_to_fahrenheit(temp_c)
print(f"{temp_c}°C = {temp_f}°F")
# Out:
# === 基本函式 ===
# 25.0°C = 77.0°F

# %%
# 5.1b 預設參數與多重返回值
print("=== 預設參數 ===")

def calculate_area(length, width=1.0):
    """計算面積（width 有預設值）"""
    return length * width

print(f"calculate_area(5.0, 3.0) = {calculate_area(5.0, 3.0)}")
print(f"calculate_area(5.0)      = {calculate_area(5.0)}  (使用預設 width=1.0)")

# 多重返回值（以元組傳回）
print("\n=== 多重返回值 ===")

def get_reactor_status():
    """返回反應器的多個操作參數"""
    temperature = 350.0
    pressure    = 10.0
    flow_rate   = 100.0
    return temperature, pressure, flow_rate  # 返回元組

temp, press, flow = get_reactor_status()
print(f"溫度： {temp}°C,  壓力： {press} bar,  流量： {flow} L/min")

# 無返回值 → 預設返回 None
def log_message(message):
    print(f"  [LOG] {message}")

result = log_message("系統啟動")
print(f"返回值為： {result}")   # None
# Out:
# === 預設參數 ===
# calculate_area(5.0, 3.0) = 15.0
# calculate_area(5.0)      = 5.0  (使用預設 width=1.0)
#
# === 多重返回值 ===
# 溫度： 350.0°C,  壓力： 10.0 bar,  流量： 100.0 L/min
#   [LOG] 系統啟動
# 返回值為： None

# %%
# 5.1c 參數類型：*args 與 **kwargs
print("=== *args：任意數量位置參數 ===")

def sum_all(*numbers):
    """加總任意個數的數字"""
    total = 0
    for num in numbers:
        total += num
    return total

print(f"sum_all(1, 2, 3)       = {sum_all(1, 2, 3)}")
print(f"sum_all(1, 2, 3, 4, 5) = {sum_all(1, 2, 3, 4, 5)}")

print("\n=== **kwargs：任意數量關鍵字參數 ===")

def print_reactor_info(**params):
    """列印反應器任意參數"""
    print("  反應器參數：")
    for key, value in params.items():
        print(f"    {key}: {value}")

print_reactor_info(temperature=350.0, pressure=10.0, type="CSTR", volume=100)

# 混合使用
print("\n=== 混合參數 ===")

def process_data(name, *values, unit="°C", **meta):
    avg = sum(values) / len(values) if values else 0
    print(f"  感測器 {name!r}: 平均={avg:.2f} {unit}")
    if meta:
        print(f"  附加資訊: {meta}")

process_data("T-101", 25.5, 26.0, 24.8, unit="°C", location="Feed Line")
# Out:
# === *args：任意數量位置參數 ===
# sum_all(1, 2, 3)       = 6
# sum_all(1, 2, 3, 4, 5) = 15
#
# === **kwargs：任意數量關鍵字參數 ===
#   反應器參數：
#     temperature: 350.0
#     pressure: 10.0
#     type: CSTR
#     volume: 100
#
# === 混合參數 ===
#   感測器 'T-101': 平均=25.43 °C
#   附加資訊: {'location': 'Feed Line'}

# %%
# 5.2 化工應用函式
print("\n=== 化工應用函式 ===")

def ideal_gas_law(P=None, V=None, n=None, T=None, R=0.0821):
    """
    理想氣體方程式： PV = nRT
    
    Parameters:
    -----------
    P : float, optional - 壓力 (atm)
    V : float, optional - 體積 (L)
    n : float, optional - 莫耳數 (mol)
    T : float, optional - 溫度 (K)
    R : float, default=0.0821 - 氣體常數
    
    Returns:
    --------
    float - 未知的變數值
    """
    if P is None:
        return (n * R * T) / V
    elif V is None:
        return (n * R * T) / P
    elif n is None:
        return (P * V) / (R * T)
    elif T is None:
        return (P * V) / (n * R)
    else:
        raise ValueError("必須有一個參數為 None")

# 計算壓力
pressure = ideal_gas_law(V=22.4, n=1.0, T=273.15)
print(f"在標準狀況下，1 mol 氣體的壓力： {pressure:.4f} atm")

# 計算莫耳數
moles = ideal_gas_law(P=1.0, V=22.4, T=273.15)
print(f"在標準狀況下，22.4 L 氣體的莫耳數： {moles:.4f} mol")
# Out:
# === 化工應用函式 ===
# 在標準狀況下，1 mol 氣體的壓力： 1.0011 atm
# 在標準狀況下，22.4 L 氣體的莫耳數： 0.9989 mol

# %%
def calculate_conversion(C0, C):
    """計算反應轉化率"""
    if C0 <= 0:
        raise ValueError("初始濃度必須大於 0")
    if C < 0:
        raise ValueError("濃度不能為負值")
    return (C0 - C) / C0

# 計算轉化率
initial_conc = 1.0
final_conc = 0.15
conversion = calculate_conversion(initial_conc, final_conc)
print(f"\n反應轉化率： {conversion:.2%}")
# Out:
# 反應轉化率： 85.00%

# %%
def heat_capacity(T, a, b, c, d=0):
    """
    計算熱容 Cp = a + bT + cT² + dT³
    
    Parameters:
    -----------
    T : float - 溫度 (K)
    a, b, c, d : float - 多項式係數
    
    Returns:
    --------
    float - 熱容 (J/(mol*K))
    """
    Cp = a + b*T + c*T**2 + d*T**3
    return Cp

# 計算水的熱容
T = 373.15  # K
Cp = heat_capacity(T, a=75.3, b=0.0, c=0.0)
print(f"\n水在 {T} K 的熱容： {Cp:.2f} J/(mol*K)")
# Out:
# 水在 373.15 K 的熱容： 75.30 J/(mol*K)

# %%
# 5.3 Lambda 函式
print("\n=== Lambda 函式 ===")

# 溫度轉換
celsius_to_kelvin = lambda c: c + 273.15
kelvin_to_celsius = lambda k: k - 273.15

temp_c = 25.0
temp_k = celsius_to_kelvin(temp_c)
print(f"{temp_c}°C = {temp_k} K")

# 用於資料處理
temperatures = [
    {"time": "08:00", "value": 25.5},
    {"time": "09:00", "value": 26.2},
    {"time": "10:00", "value": 24.8}
]

# 根據溫度值排序
sorted_temps = sorted(temperatures, key=lambda x: x["value"])
print(f"\n排序後的溫度記錄：")
for record in sorted_temps:
    print(f"  {record['time']}: {record['value']}°C")
# Out:
# === Lambda 函式 ===
# 25.0°C = 298.15 K
#
# 排序後的溫度記錄：
#   10:00: 24.8°C
#   08:00: 25.5°C
#   09:00: 26.2°C

# %% [markdown]
# ---
# ## 6. 模組與套件

# %%
# 6.1 導入模組 (import)
print("=== 導入模組語法 ===")

# 方式 1：導入整個模組
import math
result = math.sqrt(16)
print(f"math.sqrt(16) = {result}")
print(f"math.pi       = {math.pi:.6f}")

# 方式 2：導入特定函式
from math import sqrt, pi, exp, log
result2 = sqrt(16)
print(f"\nfrom math import sqrt → sqrt(16) = {result2}")

# 方式 3：導入並重新命名（別名）
import math as m
print(f"\nimport math as m → m.sin(π) = {m.sin(m.pi):.6f}")

# 方式 4：導入所有內容（不建議，容易命名衝突）
# from math import *

# 化工常用套件（示意）
print("\n=== 化工常用套件 ===")
print("import numpy as np          # 數值運算")
print("import pandas as pd         # 資料處理")
print("import matplotlib.pyplot as plt  # 資料視覺化")
print("from scipy.optimize import fsolve  # 方程式求解")
# Out:
# === 導入模組語法 ===
# math.sqrt(16) = 4.0
# math.pi       = 3.141593
#
# from math import sqrt → sqrt(16) = 4.0
#
# import math as m → m.sin(π) = 0.000000
#
# === 化工常用套件 ===
# import numpy as np          # 數值運算
# import pandas as pd         # 資料處理
# import matplotlib.pyplot as plt  # 資料視覺化
# from scipy.optimize import fsolve  # 方程式求解

# %%
# 6.2 常用內建模組
print("=== math：數學運算 ===")
import math

print(f"math.exp(1)       = {math.exp(1):.6f}   (e^1)")
print(f"math.log(math.e)  = {math.log(math.e):.6f}   (ln(e))")
print(f"math.log10(1000)  = {math.log10(1000):.6f}   (log10)")
print(f"math.sin(math.pi/2) = {math.sin(math.pi/2):.6f}")

# 化工應用：Arrhenius 方程式  k = A * exp(-Ea/RT)
A_pre  = 1e10
Ea_arr = 50000     # J/mol
R_gas  = 8.314     # J/(mol*K)
T_arr  = 350       # K
k_rate = A_pre * math.exp(-Ea_arr / (R_gas * T_arr))
print(f"\nArrhenius k at {T_arr} K = {k_rate:.4e} 1/s")

print("\n=== random：隨機數生成 ===")
import random
random.seed(42)   # 固定隨機種子，結果可重現
rand_float = random.random()
rand_int   = random.randint(1, 10)
choice     = random.choice([25.0, 26.5, 24.8])
print(f"random.random()   = {rand_float:.4f}")
print(f"random.randint(1,10) = {rand_int}")
print(f"random.choice([...]) = {choice}")

print("\n=== os：作業系統介面 ===")
import os
current_dir = os.getcwd()
print(f"os.getcwd()  = {current_dir}")
print(f"os.path.exists(): {os.path.exists(current_dir)}")
# Out:
# === math：數學運算 ===
# math.exp(1)       = 2.718282   (e^1)
# math.log(math.e)  = 1.000000   (ln(e))
# math.log10(1000)  = 3.000000   (log10)
# math.sin(math.pi/2) = 1.000000
#
# Arrhenius k at 350 K = 3.4486e+02 1/s
#
# === random：隨機數生成 ===
# random.random()   = 0.6394
# random.randint(1,10) = 1
# random.choice([...]) = 24.8
#
# === os：作業系統介面 ===
# os.getcwd()  = d:\MyGit\ChemE-3502\Unit02
# os.path.exists(): True

# %% [markdown]
# ---
# ## 7. 例外處理

# %%
# 7.1 基本例外處理
print("=== 基本例外處理 ===")

# try-except
print("測試 1: 除以零")
try:
    result = 10 / 0
except ZeroDivisionError:
    print("  ⚠ 錯誤：不能除以零")
# Out:
# === 基本例外處理 ===
# 測試 1: 除以零
#   ⚠ 錯誤：不能除以零

# %%
# 多種例外
print("\n測試 2: 字串轉整數")
try:
    number = int("abc")
except ValueError:
    print("  ⚠ 錯誤：無法轉換為整數")
# Out:
# 測試 2: 字串轉整數
#   ⚠ 錯誤：無法轉換為整數

# %%
# 7.1c 拋出例外 (raise)
print("=== 使用 raise 拋出例外 ===")

def check_temperature(temp):
    """驗證溫度是否在物理合理範圍內"""
    if temp < -273.15:
        raise ValueError(f"溫度 {temp}°C 不能低於絕對零度 (-273.15°C)")
    if temp > 1000:
        raise ValueError(f"溫度 {temp}°C 超出感測器測量上限 (1000°C)")
    return True

# 測試 1：正常溫度
print("測試 1: 正常溫度")
try:
    check_temperature(350.0)
    print("  ✓ 溫度驗證通過")
except ValueError as e:
    print(f"  ⚠ {e}")

# 測試 2：低於絕對零度
print("\n測試 2: 低於絕對零度")
try:
    check_temperature(-300)
except ValueError as e:
    print(f"  ⚠ {e}")

# 測試 3：超出範圍
print("\n測試 3: 超出測量範圍")
try:
    check_temperature(1500)
except ValueError as e:
    print(f"  ⚠ {e}")
# Out:
# === 使用 raise 拋出例外 ===
# 測試 1: 正常溫度
#   ✓ 溫度驗證通過
#
# 測試 2: 低於絕對零度
#   ⚠ 溫度 -300°C 不能低於絕對零度 (-273.15°C)
#
# 測試 3: 超出測量範圍
#   ⚠ 溫度 1500°C 超出感測器測量上限 (1000°C)

# %%
# 7.2 化工應用：參數驗證
print("\n=== 化工應用：參數驗證 ===")

def validate_reactor_parameters(temperature, pressure, flow_rate):
    """
    驗證反應器參數是否在安全範圍內
    
    Parameters:
    -----------
    temperature : float - 溫度 (°C)
    pressure : float - 壓力 (bar)
    flow_rate : float - 流量 (L/min)
    
    Raises:
    -------
    ValueError - 當參數超出安全範圍時
    """
    errors = []
    
    # 溫度檢查
    if not (250 <= temperature <= 450):
        errors.append(f"溫度 {temperature}°C 超出範圍 [250, 450]")
    
    # 壓力檢查
    if not (5 <= pressure <= 15):
        errors.append(f"壓力 {pressure} bar 超出範圍 [5, 15]")
    
    # 流量檢查
    if not (50 <= flow_rate <= 150):
        errors.append(f"流量 {flow_rate} L/min 超出範圍 [50, 150]")
    
    if errors:
        raise ValueError("\n  ".join(errors))
    
    return True

# 測試 1: 正常參數
print("測試 1: 正常參數")
try:
    validate_reactor_parameters(
        temperature=350,
        pressure=10,
        flow_rate=100
    )
    print("  ✓ 參數驗證通過")
except ValueError as e:
    print(f"  ⚠ 參數驗證失敗：\n  {e}")

# 測試 2: 異常參數
print("\n測試 2: 異常參數")
try:
    validate_reactor_parameters(
        temperature=500,  # 超出範圍
        pressure=10,
        flow_rate=100
    )
    print("  ✓ 參數驗證通過")
except ValueError as e:
    print(f"  ⚠ 參數驗證失敗：\n  {e}")
# Out:
# === 化工應用：參數驗證 ===
# 測試 1: 正常參數
#   ✓ 參數驗證通過
#
# 測試 2: 異常參數
#   ⚠ 參數驗證失敗：
#   溫度 500°C 超出範圍 [250, 450]

# %%
# 7.3 else 和 finally
print("\n=== else 和 finally ===")

def safe_divide(a, b):
    """安全的除法運算"""
    try:
        result = a / b
    except ZeroDivisionError:
        print(f"  ⚠ 錯誤：不能除以零")
        return None
    else:
        print(f"  ✓ 計算成功： {a} / {b} = {result}")
        return result
    finally:
        print(f"  → 計算完成")

print("測試 1: 正常除法")
result1 = safe_divide(10, 2)

print("\n測試 2: 除以零")
result2 = safe_divide(10, 0)
# Out:
# === else 和 finally ===
# 測試 1: 正常除法
#   ✓ 計算成功： 10 / 2 = 5.0
#   → 計算完成
#
# 測試 2: 除以零
#   ⚠ 錯誤：不能除以零
#   → 計算完成

# %% [markdown]
# ---
# ## 8. 綜合應用：化工計算案例

# %%
# 8.1 案例：反應動力學計算
print("=== 案例 1: 反應動力學計算 ===")
print("一階反應： A → B")
print()

def first_order_reaction(C0, k, t):
    """
    計算一階反應的濃度變化
    C(t) = C0 * exp(-kt)
    
    Parameters:
    -----------
    C0 : float - 初始濃度 (mol/L)
    k : float - 反應速率常數 (1/hr)
    t : float - 時間 (hr)
    
    Returns:
    --------
    float - 當前濃度 (mol/L)
    """
    import math
    return C0 * math.exp(-k * t)

# 反應參數
C0 = 1.0  # 初始濃度 (mol/L)
k = 0.1   # 反應速率常數 (1/hr)

# 計算不同時間的濃度
print(f"初始濃度： {C0} mol/L")
print(f"反應速率常數： {k} 1/hr")
print()
print("時間(hr)  濃度(mol/L)  轉化率(%)")
print("-" * 40)

time_points = [0, 1, 2, 5, 10, 20, 30]
for t in time_points:
    C = first_order_reaction(C0, k, t)
    conversion = (1 - C/C0) * 100
    print(f"{t:6.0f}     {C:9.4f}      {conversion:6.2f}")
# Out:
# === 案例 1: 反應動力學計算 ===
# 一階反應： A → B
#
# 初始濃度： 1.0 mol/L
# 反應速率常數： 0.1 1/hr
#
# 時間(hr)  濃度(mol/L)  轉化率(%)
# ----------------------------------------
#      0        1.0000        0.00
#      1        0.9048        9.52
#      2        0.8187       18.13
#      5        0.6065       39.35
#     10        0.3679       63.21
#     20        0.1353       86.47
#     30        0.0498       95.02

# %%
# 8.2 案例：理想氣體混合物計算
print("\n=== 案例 2: 理想氣體混合物計算 ===")

def calculate_partial_pressure(mole_fraction, total_pressure):
    """計算分壓"""
    return mole_fraction * total_pressure

def calculate_total_moles(components):
    """計算總莫耳數"""
    return sum(comp['moles'] for comp in components)

# 氣體混合物組成
gas_mixture = [
    {"name": "N2", "moles": 0.78},
    {"name": "O2", "moles": 0.21},
    {"name": "Ar", "moles": 0.01}
]

total_pressure = 1.0  # atm
total_moles = calculate_total_moles(gas_mixture)

print(f"總壓： {total_pressure} atm")
print(f"總莫耳數： {total_moles}")
print()
print("組分    莫耳數   莫耳分率   分壓(atm)")
print("-" * 45)

for component in gas_mixture:
    mole_fraction = component['moles'] / total_moles
    partial_pressure = calculate_partial_pressure(mole_fraction, total_pressure)
    print(f"{component['name']:6s}  {component['moles']:7.2f}   {mole_fraction:8.4f}   {partial_pressure:8.4f}")
# Out:
# === 案例 2: 理想氣體混合物計算 ===
# 總壓： 1.0 atm
# 總莫耳數： 1.0
#
# 組分    莫耳數   莫耳分率   分壓(atm)
# ---------------------------------------------
# N2         0.78     0.7800     0.7800
# O2         0.21     0.2100     0.2100
# Ar         0.01     0.0100     0.0100

# %%
# 8.3 案例：熱平衡計算
print("\n=== 案例 3: 熱平衡計算 ===")
print("兩股物流混合的熱平衡")
print()

def heat_balance(m1, Cp1, T1, m2, Cp2, T2):
    """
    計算混合後的溫度
    m1*Cp1*(T_final - T1) + m2*Cp2*(T_final - T2) = 0
    
    Parameters:
    -----------
    m1, m2 : float - 質量 (kg)
    Cp1, Cp2 : float - 比熱容 (J/(kg*K))
    T1, T2 : float - 溫度 (K)
    
    Returns:
    --------
    float - 混合後溫度 (K)
    """
    T_final = (m1*Cp1*T1 + m2*Cp2*T2) / (m1*Cp1 + m2*Cp2)
    return T_final

# 物流參數
stream1 = {
    "mass": 10.0,      # kg
    "Cp": 4180.0,      # J/(kg*K) (水)
    "temperature": 353.15  # K (80°C)
}

stream2 = {
    "mass": 5.0,       # kg
    "Cp": 4180.0,      # J/(kg*K) (水)
    "temperature": 293.15  # K (20°C)
}

# 計算混合溫度
T_final = heat_balance(
    stream1["mass"], stream1["Cp"], stream1["temperature"],
    stream2["mass"], stream2["Cp"], stream2["temperature"]
)

print(f"物流 1： {stream1['mass']} kg at {stream1['temperature']-273.15:.1f}°C")
print(f"物流 2： {stream2['mass']} kg at {stream2['temperature']-273.15:.1f}°C")
print(f"\n混合後溫度： {T_final:.2f} K ({T_final-273.15:.2f}°C)")

# 驗證能量守恆
Q1 = stream1["mass"] * stream1["Cp"] * (T_final - stream1["temperature"])
Q2 = stream2["mass"] * stream2["Cp"] * (T_final - stream2["temperature"])
Q_total = Q1 + Q2

print(f"\n能量變化檢查：")
print(f"  物流 1 能量變化： {Q1:.2f} J")
print(f"  物流 2 能量變化： {Q2:.2f} J")
print(f"  總能量變化： {Q_total:.2e} J (應接近 0)")

if abs(Q_total) < 1e-6:
    print("  ✓ 能量守恆驗證通過")
# Out:
# === 案例 3: 熱平衡計算 ===
# 兩股物流混合的熱平衡
#
# 物流 1： 10.0 kg at 80.0°C
# 物流 2： 5.0 kg at 20.0°C
#
# 混合後溫度： 333.15 K (60.00°C)
#
# 能量變化檢查：
#   物流 1 能量變化： -836000.00 J
#   物流 2 能量變化： 836000.00 J
#   總能量變化： -3.49e-09 J (應接近 0)
#   ✓ 能量守恆驗證通過

# %% [markdown]
# ---
# ## 9. 練習題

# %% [markdown]
# ### 練習 1: 溫度單位轉換器
#
# 撰寫函式進行攝氏、華氏、克氏溫度之間的轉換。
#
# **提示**：
# - 攝氏轉華氏： $F = C \times 9/5 + 32$
# - 攝氏轉克氏： $K = C + 273.15$
# - 華氏轉攝氏： $C = (F - 32) \times 5/9$

# %%
# 在此撰寫您的程式碼

def celsius_to_fahrenheit(celsius):
    """將攝氏溫度轉換為華氏溫度"""
    # TODO: 實作此函式
    pass

def celsius_to_kelvin(celsius):
    """將攝氏溫度轉換為克氏溫度"""
    # TODO: 實作此函式
    pass

def fahrenheit_to_celsius(fahrenheit):
    """將華氏溫度轉換為攝氏溫度"""
    # TODO: 實作此函式
    pass

# 測試您的函式
# temp_c = 25.0
# print(f"{temp_c}°C = {celsius_to_fahrenheit(temp_c):.2f}°F")
# print(f"{temp_c}°C = {celsius_to_kelvin(temp_c):.2f} K")

# %% [markdown]
# ### 練習 2: 感測器資料品質檢查
#
# 給定一組感測器讀數，篩選出在合理範圍內的有效資料。
#
# **任務**：
# 1. 移除超出範圍的異常值
# 2. 計算有效資料的平均值、最大值、最小值
# 3. 統計異常值的數量

# %%
# 感測器資料
sensor_data = [25.2, 25.5, -999.0, 25.8, 26.0, 999.9, 25.3, 26.2, 25.7]

# 有效範圍
MIN_VALID = 0.0
MAX_VALID = 100.0

# 在此撰寫您的程式碼
# TODO: 篩選有效資料
# TODO: 計算統計量
# TODO: 輸出結果

# %% [markdown]
# ### 練習 3: Arrhenius 方程式參數計算
#
# 根據 Arrhenius 方程式 $k = A \exp(-E_a / RT)$，計算不同溫度下的反應速率常數。
#
# **給定**：
# - 頻率因子 $A = 1.0 \times 10^{10}$ 1/s
# - 活化能 $E_a = 50000$ J/mol
# - 氣體常數 $R = 8.314 \ \mathrm{J/(mol \cdot K)}$
# - 溫度範圍： 300-400 K

# %%
# 在此撰寫您的程式碼
import math

# 參數
A = 1.0e10      # 頻率因子 (1/s)
Ea = 50000      # 活化能 (J/mol)
R = 8.314       # 氣體常數 (J/(mol*K))

# TODO: 撰寫 Arrhenius 函式
def arrhenius(T, A, Ea, R):
    """計算 Arrhenius 方程式"""
    pass

# TODO: 計算不同溫度下的速率常數
# temperatures = [300, 320, 340, 360, 380, 400]
# for T in temperatures:
#     k = arrhenius(T, A, Ea, R)
#     print(f"T = {T} K: k = {k:.4e} 1/s")

# %% [markdown]
# ---
# ## 10. 課程總結
#
# ### 本單元學習重點
#
# 在本 Notebook 中，我們實作了以下內容：
#
# ✓ **Python 基本語法**
# - `print()` 函式：基本輸出、`sep`/`end` 參數、f-string 格式化（`:.2f`、`:.2%`、`:.2e`）
# - 註解（單行 `#`、多行 `"""`）
# - 縮排規則（4 個空格）
# - 程式碼執行順序
#
# ✓ **變數與資料型態**
# - 數值型態 (int, float, complex)
# - 字串操作與方法
# - 布林值與邏輯運算
# - 變數命名規則與動態型別
# - 型態轉換 (int / float / str / tuple / set)
#
# ✓ **資料結構**
# - 串列 (List) 的操作與統計
# - 元組 (Tuple) 與解包
# - 字典 (Dictionary) 的鍵值對管理
# - 集合 (Set) 的數學運算
#
# ✓ **運算子**
# - 算術、比較、邏輯、賦值運算子
#
# ✓ **控制流程**
# - 條件語句 (if-elif-else)
# - for 迴圈與 enumerate
# - while 迴圈
# - break / continue / for-else
# - 串列生成式
#
# ✓ **函式**
# - 函式定義與位置參數
# - 預設參數與多重返回值
# - `*args` / `**kwargs`
# - Lambda 函式
# - 化工領域應用函式
#
# ✓ **模組與套件**
# - import 語法（`import`、`from ... import`、`as`）
# - 常用內建模組（math、random、os）
#
# ✓ **例外處理**
# - try-except 語法
# - 多種例外捕獲
# - raise 拋出例外
# - else / finally
# - 參數驗證與錯誤處理
#
# ✓ **綜合應用**
# - 反應動力學計算
# - 理想氣體混合物
# - 熱平衡計算
#
# ### 下一步
#
# 完成本單元後，您已具備 Python 程式設計的基礎能力。建議您：
#
# 1. **多練習**：透過練習題鞏固所學
# 2. **閱讀文件**：查閱 Python 官方文件
# 3. **繼續學習**：前往 Unit03 學習 NumPy 與 Pandas
#
# ---
#
# **恭喜您完成 Unit02 Python 程式語言基礎實作練習！**
#
# 請繼續前往 Unit03 深入學習 NumPy 與 Pandas。
